# %%
import re
import random

class RuleBot:
  #Potential Negative Responses
  neg_respo=("no","nope","nah","naw","not a chance","sorry")
  #Exit conversation KEYWORDS
  exit_commands=("quit","pause","exit","goodbye","bye","later")
  #Random starte Quesstion
  random_questions=(
      "Hello! Have you heard about Technothlon? It's a fascinating international school championship. Would you like to know more?\n",
      "Hi there! Are you interested in learning about Technothlon and its unique competitions?\n",
       "Welcome! Technothlon is a wonderful opportunity for students. Want to discover what it's all about?\n"

  )
  #techniche
  techniche_word=("techniche")
  def tech(self):
    tech=("Techniche, the Techno-Management Festival of IIT Guwahati, held during the first week of September. Other than events, the students can witness the competitions of Techniche, attend the Lecture Series of famous personalities and watch laser shows and Nite performances.\n")
    return random.choice(tech)

  #About Techno
  about_word=("about","what is technothlon","Technotlon","techno")
  def  techno(self):
      about=("Technothlon is an International School Championship organized by the IIT Guwahati. Technothlon began in 2004[1] with an aim to ‘Inspire Young Minds’.\n")
      return random.choice(about)

  #about aim
  aim_word=("motive","purpose","aim")
  def aim(self):
      aim=("Through a series of events involving mental aptitude, logic, and dexterity, Technothlon seeks to provide school students a platform to build fundamental experience and knowledge, to exercise co-ordination skills, and to think out of the box.\n",
       "As its preliminary round is conducted through several centers in India, it is a competitive test of critical thinking\n")
      return random.choice(aim)

  #about history
  history_word=("history"," how started")
  def history(self):
      history=("Technothlon 2004 - started from a small room in the campus of IIT Guwahati with a participation of 200.\n",
      "Technothlon 2005 - took its first step forward; Science Exhibitions are conducted in Local Schools of Guwahati. Participation increased to 350.\n",
      "Technothlon 2006 covers the seven sisters. Participation went over 700.\n",
      "Technothlon 2007 reached Hyderabad. Participation reached the three figures.\n",
      "Technothlon 2008 became National. Participation reached four figures.\n")
      return random.choice(history)

  #about Eligibility
  eligibility_word=("eligible","process")
  def eligibility(self):
      eligibility=("Technothlon is conducted for students of class IX to XII. There are two squads for which the examination is held. The first is the Junior squad and the second is the Hauts squad. For a student to appear in the Junior squad examination, he/she must be VIII class passed and must not have appeared for the X boards i.e. The students should be studying in IX or X STD. For a student to be appearing for the Hauts squad examination, he/she must have passed the X board examination and not appeared for the XII board examination. The members can belong to the same class or as well as different class. For example: a team consisting of one member from class IX and one of class X is perfectly acceptable. The basic requirements for team formation is that they should consist of exactly two members from the same squad and the same school.")
      return random.choice(eligibility)

  #mode of registration
  mode_word=("registration","mode")
  def mode(self):
      mode=("The interested students can register themselves for the examination online or offline. Technothlon is conducted over various cities and centers with the help of city representatives. The city representatives are responsible for collecting the registrations offline. Participating schools can collect the registration fees themselves and then prepare a demand draft to be handed over to the city representatives. You can visit its officiall website:https://technothlon.techniche.org.in/")
      return random.choice(self)


  #Examination
  exam_word=("examination","exam","test")
  def exam(self):
      exam=("Students participate in teams of two(individual this year due to pandemic). There are two duos:1.Junior Duo – Students of classes 9th and 10th. 2,Hauts Duo – Students of classes 11th and 12th\n",
        "Technothlon is held in two stages:1.Prelims: Generally held on 2nd or 3rd Sundays of July every Year. 2.Mains: To be held at IIT Guwahati during Techniche- Held in 1st week of Sept every year\n",
        "Prelims is in general an objective written exam. It involves no syllabus or general knowledge requirement and relies solely on the student's logical and analytic thinking abilities. The exam is generally of 2 and ½ hour length. The question paper will have various sections like maths, puzzles, code crunchers etc. Each section has its own unique marking scheme. It is held nationwide, at selected cities on the 3rd Sunday of the month of July.\n"
        "Mains is an event based competition. The selected teams compete against each other of the same squad to complete the events. Each team will have to face 3 events from which top 5 teams from each squad will be selected for the Final Showdown. The events, like Prelims, do not require any prerequisite knowledge and students will be taught any extra knowledge they require. The events will vary every year. In addition to these, students can attend the workshops and fun events to spend the night. Mains is conducted during Techniche, the Techno-Management Festival of IIT Guwahati, held during the first week of September. Other than events, the students can witness the competitions of Techniche, attend the Lecture Series of famous personalities and watch laser shows and Nite performances.\n")
      return random.choice(exam)


#Technopedia
  techno_word=("technopedia","Techno Coup D'œi")
  def technopedia(self):
      technopedia=("Technopedia is the online module of Technothlon providing the participants an exclusive experience before they give the preliminary exam, with monthly quizzes and the various articles which are added to the module regularly. It aims at increasing the thinking capabilities and analytical reasoning and also helping them prepare for Prelims\n",
             "Technopedia generally consists of 10 questions divided into 10 levels. A higher level gets unlocked only after answering the questions in the preceding level correctly. It is updated on a monthly basis for about 6 months before the preliminary examination of Technothlon. Only the students who have registered for prelims may log onto Technopedia using the provided ID and password. Participants who are consistent in clearing Technopedia monthly may expect a SURPRISE gift during Techniche.\n",
             "Techno Coup D'œil is a series of questions published on the official Facebook page of Technothlon, giving the followers of the page a feel of what the actual paper might be like.\n")
      return random.choice(technopedia)


#selection
  selection_word=("select","selecetion","basis")
  def sel(self):
      selection=("1.Top 25 teams of each squad are selected on basis of their score in the Prelims examination.\n"
           "2.Top teams, which perform excellently from each of these squads are selected from the Events in Mains for the Final Showdown\n"
           "3.The winner of the Final Showdown is declared the Technothlon Champion.\n")
      return random.choice(selection)

#Rewards
  reward_word=("reward","prize","winner")
  def reward(self):
      reward=("Other than the top 25 teams which are selected for mains in each squad; the next 200 teams in both the squads are awarded Silver certificates from Techniche, IIT Guwahati.\n",
        "All the participants of the Mains will be served with accommodation for the four days during their stay at IIT Guwahati.\n",
        "All the teams attending the Mains events at IITG will also be given Gold certificates from Techniche, IITG.\n")
      return random.choice(reward)

#fees
  fee_word=("fee","prgistration price","charges")
  def fee(self):
      fee=("echnothlon and Techniche, being non-profit organizations charge only an amount of Rs. 200 per team (of two students) as registration fees for the Prelims Examination conducted all over India which covers the examination conduction expenses.\n")
      return random.choice(fee)

#Heads
  head_word=("students","heads","Examiner")
  def head(self):
      head=("Team 2024:\n"
      "South Zone:Sandeep Charlie,Sarvagna Grandhi\n"
      "Central Zone:Hrishikeshan N\n"
      "West Zone:Sarvesh Murkute\n"
      "East Zone:Rahul Kumar\n"
      "North Zone:Siva Keerthan,Utkarsh Verma\n")
      return random.choice(head)

#Zone
  zone_word=("Zone")
  def zone(self):
      zone=(
      "South Zone:Sandeep Charlie,Sarvagna Grandhi\n",
      "Central Zone:Hrishikeshan N\n",
      "West Zone:Sarvesh Murkute\n",
      "East Zone:Rahul Kumar\n",
      "North Zone:Siva Keerthan,Utkarsh Verma\n")
      return random.choice(zone)

  def greet(self):
      self.name=input("What is your name\n")
      will_help=input(f"Hi {self.name}, I am Techno-Bot.Will you help me learn about Technothlon?\n")
      if will_help in self.neg_respo:
        print("Ok,have a nice day!")
      return self.chat()



  def make_exit(self,reply):
      for command in self.exit_commands:
          if reply==command:
           print("Best Luck for your Exam!")
          return True

  def chat(self):
       reply=input(random.choice(self.random_questions)).lower()
       while not self.make_exit(reply):
        reply=input(self.match_reply(reply))



  def __init__(self):
   self.hi = {
            'tech': r'.*\btechniche\b.*',
            'echno': r'.*\b(about|what is technothlon|technotlon|techno)\b.*',
            'aim': r'.*\b(motive|purpose|aim)\b.*',
            'history': r'.*\b(history|how started)\b.*',
            'eligibility': r'.*\b(eligible|process)\b.*',
            'mode': r'.*\b(registration|mode)\b.*',
            'exam': r'.*\b(examination|exam|test)\b.*',
            'technopedia': r'.*\b(technopedia|Techno Coup D\b.*',
            'selection': r'.*\b(select|selection|basis)\b.*',
            'reward': r'.*\b(reward|prize|winner)\b.*',
            'fee': r'.*\b(fee|registration price|charges)\b.*',
            'head': r'.*\b(students|heads|examiner)\b.*'
   }

  def match_reply(self,reply):
    for key,value in self.hi.items():
      intent=key
      regex_pattern=value
      found_match=re.match(regex_pattern,reply)
      if found_match and itent=='tech':
        return self.tech()
      elif found_match and intent=="techno":
        return self.techno()
      elif found_match and intent=='aim':
        return self.aim()
      elif found_match and intent=='history':
        return self.history()
      elif found_match and intent=="eligibility":
        return self.eligibility()
      elif found_match and intent=='mode':
        return self.mode()
      elif found_match and intent=='exam':
        return self.exam()
      elif found_match and intent=="techno":
        return self.techno()
      elif found_match and intent=='technopedia':
        return self.technopedia()
      elif found_match and intent=='sel':
        return self.sel()
      elif found_match and intent=="reward":
        return self.reward()
      elif found_match and intent=='fee':
        return self.fee()
      elif found_match and intent=='head':
        return self.head()
    if not found_match:
      return self.no_match_intent()

Bot=RuleBot()
Bot.greet()
# Out:
# What is your name
# SHUBHAM KUMAR SONI
# Hi SHUBHAM KUMAR SONI, I am Techno-Bot.Will you help me learn about Technothlon?
# Tell me more aubout technothlon
# Hello! Have you heard about Technothlon? It's a fascinating international school championship. Would you like to know more?
# Tell me more aubout technothlon
